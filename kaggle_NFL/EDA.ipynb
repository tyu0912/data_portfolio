# %%
import pandas as pd
import numpy as np

# %%
injuries = pd.read_csv('InjuryRecord.csv')

# %%
injuries.head()
# Out:
#    PlayerKey   GameID     PlayKey BodyPart    Surface  DM_M1  DM_M7  DM_M28  \
# 0      39873  39873-4  39873-4-32     Knee  Synthetic      1      1       1
# 1      46074  46074-7  46074-7-26     Knee    Natural      1      1       0
# 2      36557  36557-1  36557-1-70    Ankle  Synthetic      1      1       1
# 3      46646  46646-3  46646-3-30    Ankle    Natural      1      0       0
# 4      43532  43532-5  43532-5-69    Ankle  Synthetic      1      1       1
#
#    DM_M42
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1

# %%
playlist = pd.read_csv('PlayList.csv')

# %%
playlist.head()
# Out:
#    PlayerKey   GameID    PlayKey RosterPosition  PlayerDay  PlayerGame  \
# 0      26624  26624-1  26624-1-1    Quarterback          1           1
# 1      26624  26624-1  26624-1-2    Quarterback          1           1
# 2      26624  26624-1  26624-1-3    Quarterback          1           1
# 3      26624  26624-1  26624-1-4    Quarterback          1           1
# 4      26624  26624-1  26624-1-5    Quarterback          1           1
#
#   StadiumType  FieldType  Temperature         Weather PlayType  \
# 0     Outdoor  Synthetic           63  Clear and warm     Pass
# 1     Outdoor  Synthetic           63  Clear and warm     Pass
# 2     Outdoor  Synthetic           63  Clear and warm     Rush
# 3     Outdoor  Synthetic           63  Clear and warm     Rush
# 4     Outdoor  Synthetic           63  Clear and warm     Pass
#
#    PlayerGamePlay Position PositionGroup
# 0               1       QB            QB
# 1               2       QB            QB
# ...

# %%
p1 = playlist[playlist['PlayerKey'] == 36557]

# %%
p1[p1['PlayKey'] == '36557-1-70']
# Out:
#        PlayerKey   GameID     PlayKey RosterPosition  PlayerDay  PlayerGame  \
# 26675      36557  36557-1  36557-1-70         Safety          1           1
#
#       StadiumType  FieldType  Temperature         Weather PlayType  \
# 26675     Outdoor  Synthetic           63  Clear and warm     Pass
#
#        PlayerGamePlay Position PositionGroup
# 26675              70       SS            DB

# %%
set(injuries['BodyPart'])
# Out:
# {'Ankle', 'Foot', 'Heel', 'Knee', 'Toes'}

# %%
for i in set(injuries['BodyPart']):
    df = injuries[injuries['BodyPart'] == i]
    s = len(df[df.Surface == 'Synthetic'])
    n = len(df[df.Surface == 'Natural'])
    print("For {} injury: sythetic={}, natural={}".format(i, s, n))
# Out:
# For Knee injury: sythetic=24, natural=24
# For Heel injury: sythetic=0, natural=1
# For Ankle injury: sythetic=25, natural=17
# For Toes injury: sythetic=6, natural=1
# For Foot injury: sythetic=2, natural=5

# %%
plays = pd.read_csv('PlayerTrackData.csv')

# %%
plays.head()
# Out:
#      PlayKey  time                 event      x      y     dir   dis       o  \
# 0  26624-1-1   0.0  huddle_start_offense  87.46  28.93  288.24  0.01  262.33
# 1  26624-1-1   0.1                   NaN  87.45  28.92  283.91  0.01  261.69
# 2  26624-1-1   0.2                   NaN  87.44  28.92  280.40  0.01  261.17
# 3  26624-1-1   0.3                   NaN  87.44  28.92  278.79  0.01  260.66
# 4  26624-1-1   0.4                   NaN  87.44  28.92  275.44  0.01  260.27
#
#       s
# 0  0.13
# 1  0.12
# 2  0.12
# 3  0.10
# 4  0.09

# %%
plays[plays.PlayKey == '36557-1-70']
# Out:
#             PlayKey  time     event      x      y     dir   dis       o     s
# 7727218  36557-1-70   0.0  line_set  83.69  30.37   64.58  0.06   18.69  0.59
# 7727219  36557-1-70   0.1       NaN  83.74  30.39   64.68  0.06   22.85  0.55
# 7727220  36557-1-70   0.2       NaN  83.79  30.40   64.47  0.05   26.83  0.50
# 7727221  36557-1-70   0.3       NaN  83.84  30.43   64.51  0.06   29.94  0.45
# 7727222  36557-1-70   0.4       NaN  83.89  30.43   62.67  0.05   31.88  0.40
# 7727223  36557-1-70   0.5       NaN  83.93  30.44   58.33  0.04   33.10  0.34
# 7727224  36557-1-70   0.6       NaN  83.97  30.43   53.69  0.04   33.74  0.27
# 7727225  36557-1-70   0.7       NaN  83.98  30.46   47.76  0.03   33.61  0.19
# 7727226  36557-1-70   0.8       NaN  84.00  30.49   32.39  0.03   32.12  0.13
# 7727227  36557-1-70   0.9       NaN  84.01  30.49  359.80  0.01   29.50  0.10
# 7727228  36557-1-70   1.0       NaN  84.01  30.50  323.47  0.01   26.84  0.12
# ...
